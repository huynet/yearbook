# %%
import os
os.getcwd()
# Out:
# '/Users/pharvard/Desktop/hoa1'

# %%
for root, dirs, files in os.walk(top, topdown=False):
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6e8d60c8e86c> in <module>()
# ----> 1 for root, dirs, files in os.walk(top, topdown=False):
#       2     for name in dirs:
#       3         print(os.path.join(root, name))
#
# NameError: name 'top' is not defined

# %%
list = os.listdir()

# %%
list = ['33 - Nguyễn Hà Nhi.jpg',
 '02 - Nguyễn Hồng Anh.jpg',
 '04 - Phạm Quang Anh.jpg',
 '36 - Nguyễn Minh Thư.jpg',
 '24 - Đặng Thanh Lâm.jpg',
 '41 - Nguyễn Thị Khánh Vân.png',
 '35 - Lê Hà Thu.jpg',
 '23 - Bùi Khắc Lâm.jpg',
 '05 - Nguyễn Kim Chung.jpg',
 '37 - Đỗ Thành Trung.jpg',
 '21 - Trần Thanh Hương.jpg',
 '27 - Bùi Ngọc Minh.jpg',
 '12 - Trần Minh Đức.jpg',
 '08 - Nguyễn Thái Duy.jpg',
 '10 - Lê Trần Anh Đức.jpg',
 '32 - Đoàn Bích Ngọc.jpg',
 '01 - Tăng Quốc An.jpg',
 '03 - Nguyễn Huy Anh.jpg',
 '39 - Hà Duy Tùng.jpg',
 '26 - Đỗ Trần Minh Long.jpg',
 '11 - Nguyễn Hoàng Đức.jpg',
 '25 - Nguyễn Hoàng Long.jpg',
 '22 - Trần Đăng Khôi.jpg',
 '16 - Phạm Việt Hùng.jpg',
 '34 - Trần Hồng Quân.jpg',
 '14 - Lưu Việt Hà.jpg',
 '38 - Trịnh Minh Tuấn.jpg',
 '40 - Trần Thanh Tùng.jpg',
 '29 - Vũ Dương Anh Minh.jpg',
 '30 - Nguyễn Khắc Hải Nam.jpg',
 '19 - Phạm Quang Huy.jpg',
 '20 - Nguyễn Quang Hưng.jpg',
 '07 - Đỗ Hoàng Duy.jpg',
 '13 - Bùi Thanh Hồng Giang.jpg',
 '17 - Trịnh Tuấn Hùng.JPG',
 '06 - Nguyễn Quốc Cường.jpg',
 '28 - Lê Thị Nguyệt Minh.jpg',
 '09 - Nguyễn Vũ Thuỳ Dương.jpg']

# %%
list[23]
# Out:
# '16 - Phạm Việt Hùng.jpg'

# %%
import numpy as np
import cv2 as cv
for name in list:
    img = cv.imread(name)
    res = cv.resize(img,None,fx=0.5, fy=0.5, interpolation = cv.INTER_CUBIC)

# %%
pics = os.listdir()
pics
# Out:
# ['33 - Nguyễn Hà Nhi.jpg',
#  '02 - Nguyễn Hồng Anh.jpg',
#  '04 - Phạm Quang Anh.jpg',
#  '36 - Nguyễn Minh Thư.jpg',
#  '24 - Đặng Thanh Lâm.jpg',
#  '41 - Nguyễn Thị Khánh Vân.jpg',
#  '35 - Lê Hà Thu.jpg',
#  '.DS_Store',
#  '23 - Bùi Khắc Lâm.jpg',
#  '05 - Nguyễn Kim Chung.jpg',
#  '37 - Đỗ Thành Trung.jpg',
#  'Untitled.ipynb',
#  '21 - Trần Thanh Hương.jpg',
#  '27 - Bùi Ngọc Minh.jpg',
#  '12 - Trần Minh Đức.jpg',
#  '08 - Nguyễn Thái Duy.jpg',
#  '10 - Lê Trần Anh Đức.jpg',
#  '32 - Đoàn Bích Ngọc.jpg',
#  '01 - Tăng Quốc An.jpg',
#  '03 - Nguyễn Huy Anh.jpg',
#  '39 - Hà Duy Tùng.jpg',
#  '26 - Đỗ Trần Minh Long.jpg',
#  '11 - Nguyễn Hoàng Đức.jpg',
#  '25 - Nguyễn Hoàng Long.jpg',
#  '22 - Trần Đăng Khôi.jpg',
#  '16 - Phạm Việt Hùng.jpg',
#  '34 - Trần Hồng Quân.jpg',
#  '14 - Lưu Việt Hà.jpg',
#  '38 - Trịnh Minh Tuấn.jpg',
#  '40 - Trần Thanh Tùng.jpg',
# ...

# %%
pics = ['33 - Nguyễn Hà Nhi.jpg',
 '02 - Nguyễn Hồng Anh.jpg',
 '04 - Phạm Quang Anh.jpg',
 '36 - Nguyễn Minh Thư.jpg',
 '24 - Đặng Thanh Lâm.jpg',
 '41 - Nguyễn Thị Khánh Vân.jpg',
 '35 - Lê Hà Thu.jpg',
 '23 - Bùi Khắc Lâm.jpg',
 '05 - Nguyễn Kim Chung.jpg',
 '37 - Đỗ Thành Trung.jpg',
 '21 - Trần Thanh Hương.jpg',
 '27 - Bùi Ngọc Minh.jpg',
 '12 - Trần Minh Đức.jpg',
 '08 - Nguyễn Thái Duy.jpg',
 '10 - Lê Trần Anh Đức.jpg',
 '32 - Đoàn Bích Ngọc.jpg',
 '01 - Tăng Quốc An.jpg',
 '03 - Nguyễn Huy Anh.jpg',
 '39 - Hà Duy Tùng.jpg',
 '26 - Đỗ Trần Minh Long.jpg',
 '11 - Nguyễn Hoàng Đức.jpg',
 '25 - Nguyễn Hoàng Long.jpg',
 '22 - Trần Đăng Khôi.jpg',
 '16 - Phạm Việt Hùng.jpg',
 '34 - Trần Hồng Quân.jpg',
 '14 - Lưu Việt Hà.jpg',
 '38 - Trịnh Minh Tuấn.jpg',
 '40 - Trần Thanh Tùng.jpg',
 '29 - Vũ Dương Anh Minh.jpg',
 '30 - Nguyễn Khắc Hải Nam.jpg',
 '19 - Phạm Quang Huy.jpg',
 '20 - Nguyễn Quang Hưng.jpg',
 '07 - Đỗ Hoàng Duy.jpg',
 '13 - Bùi Thanh Hồng Giang.jpg',
 '17 - Trịnh Tuấn Hùng.jpg',
 '06 - Nguyễn Quốc Cường.jpg',
 '28 - Lê Thị Nguyệt Minh.jpg',
 '09-Nguyễn Vũ Thuỳ Dương.jpg',]

# %%
pawn = '''
			<div class="gallerio filtr-item thumbnail" data-category="all,hoa" data-sort="hoa">
				<img src="images/places/{0}" alt="">
				<div class="desc">{1}</div>
			</div>'''

# %%
for pic in pics:
    print(pawn.format(name, name))
# Out:
# 			<div class="gallerio filtr-item thumbnail" data-category="all,hoa" data-sort="hoa">
# 				<img src="images/places/09-Nguyễn Vũ Thuỳ Dương.jpg" alt="">
# 				<div class="desc">09-Nguyễn Vũ Thuỳ Dương.jpg</div>
# 			</div>
#
# 			<div class="gallerio filtr-item thumbnail" data-category="all,hoa" data-sort="hoa">
# 				<img src="images/places/09-Nguyễn Vũ Thuỳ Dương.jpg" alt="">
# 				<div class="desc">09-Nguyễn Vũ Thuỳ Dương.jpg</div>
# 			</div>
#
# 			<div class="gallerio filtr-item thumbnail" data-category="all,hoa" data-sort="hoa">
# 				<img src="images/places/09-Nguyễn Vũ Thuỳ Dương.jpg" alt="">
# 				<div class="desc">09-Nguyễn Vũ Thuỳ Dương.jpg</div>
# 			</div>
#
# 			<div class="gallerio filtr-item thumbnail" data-category="all,hoa" data-sort="hoa">
# 				<img src="images/places/09-Nguyễn Vũ Thuỳ Dương.jpg" alt="">
# 				<div class="desc">09-Nguyễn Vũ Thuỳ Dương.jpg</div>
# 			</div>
#
# ...

# %%
print(pawn)
# Out:
# 			<div class="gallerio filtr-item thumbnail" data-category="all,places" data-sort="streets">
# 				<img src="images/places/arch (4).jpg" alt="">
# 				<div class="desc">Streets</div>
# 			</div>
